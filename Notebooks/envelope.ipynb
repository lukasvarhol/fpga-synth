# %% [markdown]
# # Envelope Generator
# This notebook details the implementation of the envelope generator.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

FS = 48_000

# we want a simple FSM:
# note pressed -> attack -> decay -> sustain
# note pressed -> release

# therefore this should not be implemented with a table as we would have to use variable table lengths 
# in order to meet the different note hold durations.
